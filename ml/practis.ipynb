# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

img=cv2.imread('aa.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

k1=np.array([[0,-1,-1],[1,0,-1],[1,1,0]])
k2=np.array([[-1,-1,0],[-1,0,1],[0,1,1]])
k3=np.array([[1,0,0],[0,0,0],[0,0,-1]])
k4=np.array([[0,0,1],[0,0,0],[-1,0,0]])

img1=cv2.filter2D(img,-1,k1)
img2=cv2.filter2D(img,-1,k2)
img3=cv2.filter2D(img,-1,k3)
img4=cv2.filter2D(img,-1,k4)

plt.subplot(2,3,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(2,3,2),plt.imshow(img1,cmap='gray'),plt.title('k1'),plt.axis('off')
plt.subplot(2,3,3),plt.imshow(img2,cmap='gray'),plt.title('k2'),plt.axis('off')
plt.subplot(2,3,4),plt.imshow(img3,cmap='gray'),plt.title('k3'),plt.axis('off')
plt.subplot(2,3,5),plt.imshow(img4,cmap='gray'),plt.title('k4'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'k4'}>,
#  <matplotlib.image.AxesImage at 0x196f3a969b0>,
#  Text(0.5, 1.0, 'k4'),
#  (-0.5, 224.5, 224.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

img=cv2.imread('m.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

k1=np.array([[0,-1,-1],[1,0,-1],[1,1,0]])
k2=np.array([[-1,-1,0],[-1,0,1],[0,1,1]])
k3=np.array([[1,0,0],[0,0,0],[0,0,-1]])
k4=np.array([[0,0,1],[0,0,0],[-1,0,0]])

img1=cv2.filter2D(img,-1,k1)
img2=cv2.filter2D(img,-1,k2)
img3=cv2.filter2D(img,-1,k3)
img4=cv2.filter2D(img,-1,k4)

plt.subplot(2,3,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(2,3,2),plt.imshow(img1,cmap='gray'),plt.title('k1'),plt.axis('off')
plt.subplot(2,3,3),plt.imshow(img2,cmap='gray'),plt.title('k2'),plt.axis('off')
plt.subplot(2,3,4),plt.imshow(img3,cmap='gray'),plt.title('k3'),plt.axis('off')
plt.subplot(2,3,5),plt.imshow(img4,cmap='gray'),plt.title('k4'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'k4'}>,
#  <matplotlib.image.AxesImage at 0x196f3c9ed70>,
#  Text(0.5, 1.0, 'k4'),
#  (-0.5, 218.5, 229.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

img=cv2.imread('ab.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

k1=np.array([[0,-1,-1],[1,0,-1],[1,1,0]])
k2=np.array([[-1,-1,0],[-1,0,1],[0,1,1]])
k3=np.array([[1,0,0],[0,0,0],[0,0,-1]])
k4=np.array([[0,0,1],[0,0,0],[-1,0,0]])
k5=np.array([[1,1,0],[1,-1,1],[0,-1,-1]])


img1=cv2.filter2D(img,-1,k1)
img2=cv2.filter2D(img,-1,k2)
img3=cv2.filter2D(img,-1,k3)
img4=cv2.filter2D(img,-1,k4)
img5=cv2.filter2D(img,-1,k5)

plt.subplot(2,5,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(2,5,2),plt.imshow(img1,cmap='gray'),plt.title('k1'),plt.axis('off')
plt.subplot(2,5,3),plt.imshow(img2,cmap='gray'),plt.title('k2'),plt.axis('off')
plt.subplot(2,5,4),plt.imshow(img3,cmap='gray'),plt.title('k3'),plt.axis('off')
plt.subplot(2,5,5),plt.imshow(img4,cmap='gray'),plt.title('k4'),plt.axis('off')
plt.subplot(2,5,6),plt.imshow(img5,cmap='gray'),plt.title('k5'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'k5'}>,
#  <matplotlib.image.AxesImage at 0x213f99ef0d0>,
#  Text(0.5, 1.0, 'k5'),
#  (-0.5, 224.5, 224.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

img=cv2.imread('ab.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

k1=np.array([[0,-1,-1],[1,0,-1],[1,1,0]])
k2=np.array([[-1,-1,0],[-1,0,1],[0,1,1]])
k3=np.array([[1,0,0],[0,0,0],[0,0,-1]])
k4=np.array([[0,0,1],[0,0,0],[-1,0,0]])
k5=np.array([[1,1,0],[1,-1,1],[0,-1,-1]])


img1=cv2.filter2D(img,-1,k1)
img2=cv2.filter2D(img,-1,k2)
img3=cv2.filter2D(img,-1,k3)
img4=cv2.filter2D(img,-1,k4)
img5=cv2.filter2D(img,-1,k5)

plt.subplot(2,5,1),plt.imshow(img),plt.title('source'),plt.axis('off')
plt.subplot(2,5,2),plt.imshow(img1,cmap='gray'),plt.title('k1'),plt.axis('off')
plt.subplot(2,5,3),plt.imshow(img2,cmap='gray'),plt.title('k2'),plt.axis('off')
plt.subplot(2,5,4),plt.imshow(img3,cmap='gray'),plt.title('k3'),plt.axis('off')
plt.subplot(2,5,5),plt.imshow(img4,cmap='gray'),plt.title('k4'),plt.axis('off')
plt.subplot(2,5,6),plt.imshow(img5,cmap='gray'),plt.title('k5'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'k5'}>,
#  <matplotlib.image.AxesImage at 0x213f99ef0d0>,
#  Text(0.5, 1.0, 'k5'),
#  (-0.5, 224.5, 224.5, -0.5))
